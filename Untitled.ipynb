# %%
# !pip install pandas

# %%
import pandas as pd
#dataframe create

# %%
df=pd.DataFrame([1,2,3])
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
data={
      "Name":["abid alam","salahuddin","ahsan"],
      "age":[34,23,77],
      "sallerry":[12000,65777,67667] 
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#          Name  age  sallerry
# 0   abid alam   34     12000
# 1  salahuddin   23     65777
# 2       ahsan   77     67667

# %%
df.head(4)
# Out:
#          Name  age  sallerry
# 0   abid alam   34     12000
# 1  salahuddin   23     65777
# 2       ahsan   77     67667

# %%
df.tail(1)
# Out:
#     Name  age  sallerry
# 2  ahsan   77     67667

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'age', 'sallerry'], dtype='object')

# %%
df.rename(columns={"sallerry": "salary"},inplace=True)

# %%
df
# Out:
#          Name  age  salary
# 0   abid alam   34   12000
# 1  salahuddin   23   65777
# 2       ahsan   77   67667

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   age     3 non-null      int64
#  2   salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#              age        salary
# count   3.000000      3.000000
# mean   44.666667  48481.333333
# std    28.536526  31607.891204
# min    23.000000  12000.000000
# 25%    28.500000  38888.500000
# 50%    34.000000  65777.000000
# 75%    55.500000  66722.000000
# max    77.000000  67667.000000

# %%
#save and load data fram csv

# %%
df
# Out:
#          Name  age  salary
# 0   abid alam   34   12000
# 1  salahuddin   23   65777
# 2       ahsan   77   67667

# %%
df.to_csv("test_data.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HB LAPTOP POINT'

# %%
load_df=pd.read_csv("test_data.csv")
load_df
# Out:
#          Name  age  salary
# 0   abid alam   34   12000
# 1  salahuddin   23   65777
# 2       ahsan   77   67667

# %%
  #row coliumns selections
df[["Name"]]
# Out:
#          Name
# 0   abid alam
# 1  salahuddin
# 2       ahsan

# %%
df.loc[df.Name=="abid alam"]
# Out:
#         Name  age  salary
# 0  abid alam   34   12000

# %%
df.loc[(df.Name=="abid alam")& (df.salary>=10000)]
# Out:
#         Name  age  salary
# 0  abid alam   34   12000

# %%
df.loc[0:2]
# Out:
#          Name  age  salary
# 0   abid alam   34   12000
# 1  salahuddin   23   65777
# 2       ahsan   77   67667

# %%
# df.iloc[0]
df.iloc[0:2]
# Out:
#          Name  age  salary
# 0   abid alam   34   12000
# 1  salahuddin   23   65777

# %%
 df
# Out:
#          Name  age  salary
# 0   abid alam   34   12000
# 1  salahuddin   23   65777
# 2       ahsan   77   67667

# %%
df_age_filter=df[df["age"]>30]

# %%
df_age_filter
# Out:
#         Name  age  salary
# 0  abid alam   34   12000
# 2      ahsan   77   67667

# %%
df[(df["age"]>=30)& (df["salary"]>=67000)]
# Out:
#     Name  age  salary
# 2  ahsan   77   67667

# %%
df["Team"]=["CEO","HR","DA"]
df
# Out:
#          Name  age  salary Team
# 0   abid alam   34   12000  CEO
# 1  salahuddin   23   65777   HR
# 2       ahsan   77   67667   DA

# %%
df["bonus"]=df["salary"]*0.2
df
# Out:
#          Name  age  salary Team    bonus
# 0   abid alam   34   12000  CEO   2400.0
# 1  salahuddin   23   65777   HR  13155.4
# 2       ahsan   77   67667   DA  13533.4

# %%
df.loc[len(df)]=["abc",33,4567,"DA",3444]
df
# Out:
#          Name  age  salary Team    bonus
# 0   abid alam   34   12000  CEO   2400.0
# 1  salahuddin   23   65777   HR  13155.4
# 2       ahsan   77   67667   DA  13533.4
# 3         abc   33    4567   DA   3444.0

# %%
# %history -f main1.py
